# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString

# %% [markdown]
# # Read-In data

# %%
stops = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/01_Text/04_Abbildungen/Kapitel_4/google_transit/stops.txt"
shapes = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/01_Text/04_Abbildungen/Kapitel_4/google_transit/shapes.txt"
trips = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/01_Text/04_Abbildungen/Kapitel_4/google_transit/trips.txt"
routes = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/01_Text/04_Abbildungen/Kapitel_4/google_transit/routes.txt"

# %%
df_stops = pd.read_csv(stops)
df_shapes = pd.read_csv(shapes)
df_trips = pd.read_csv(trips)
df_routes = pd.read_csv(routes)

# %%
df_stops.head(3)
# Out:
#             stop_id  stop_name   stop_lat  stop_lon
# 0  de:08111:100:1:1  Stammheim  48.850046  9.156174
# 1  de:08111:100:2:3  Stammheim  48.849443  9.156022
# 2  de:08111:100:2:4  Stammheim  48.850217  9.156093

# %%
df_shapes.head(3)
# Out:
#           shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0  10-12-j21-1.1.H     48.806804      9.525427                  1
# 1  10-12-j21-1.1.H     48.806196      9.523318                  2
# 2  10-12-j21-1.1.H     48.805813      9.522288                  3
#
#    shape_dist_traveled
# 0                 0.00
# 1               168.63
# 2               255.25

# %%
df_trips.head(3)
# Out:
#       route_id service_id                  trip_id          shape_id  \
# 0  10-12-j21-1      T0#10  100.T0.10-12-j21-1.13.R  10-12-j21-1.13.R
# 1  10-12-j21-1      T0#10    11.T0.10-12-j21-1.6.H   10-12-j21-1.6.H
# 2  10-12-j21-1      T0#10    13.T0.10-12-j21-1.6.H   10-12-j21-1.6.H
#
#    trip_headsign  direction_id  block_id
# 0     Schorndorf             1       NaN
# 1  Esslingen (N)             0       NaN
# 2  Esslingen (N)             0       NaN

# %%
df_routes.head(3)
# Out:
#       route_id  agency_id route_short_name  \
# 0  10-12-j21-1        NaN              S12
# 1  10-15-j21-1        NaN              S15
# 2  10-15-j21-2        NaN              S15
#
#                                    route_long_name  route_type route_color  \
# 0           Schorndorf - Bad Cannstatt - Esslingen         109      83b23b
# 1  Bietigheim - Feuerbach - Vaihingen - Herrenberg         109      83b23b
# 2  Bietigheim - Feuerbach - Vaihingen - Herrenberg         109      83b23b
#
#   route_text_color
# 0           FFFFFF
# 1           FFFFFF
# 2           FFFFFF

# %% [markdown]
# # Create shapes

# %%
gdf_shapes = gpd.GeoDataFrame(
    df_shapes, geometry=gpd.points_from_xy(df_shapes.shape_pt_lon, df_shapes.shape_pt_lat))

gdf_lines = gdf_shapes.dissolve(by='shape_id').reset_index(drop=False)
gdf_lines = gdf_lines[['shape_id', 'geometry']]
gdf_lines['geometry'] = gdf_lines['geometry'].apply(lambda x: LineString(x))

# %%
gdf_lines.head(3)
# Out:
#           shape_id                                           geometry
# 0   10-1-j21-1.1.H  LINESTRING (9.10464 48.74838, 9.10466 48.74876...
# 1  10-1-j21-1.10.R  LINESTRING (9.15655 48.77009, 9.15798 48.77046...
# 2  10-1-j21-1.11.R  LINESTRING (9.00456 48.68792, 9.00551 48.68845...

# %% [markdown]
# # Merge

# %%
gdf_trips = df_trips.merge(gdf_lines, how ='left')
gdf_trips = gdf_trips.merge(df_routes, how = 'left')

# %%
gdf_trips = gpd.GeoDataFrame(
    gdf_trips.drop(columns=['geometry']), geometry=gdf_trips['geometry'])

# %%
gdf_trips = gdf_trips[['route_short_name', 'route_type', 'route_color', 'geometry']]
gdf_trips = gdf_trips[gdf_trips['geometry'] != None]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-40f265dbb4fe> in <module>
#       1 gdf_trips = gdf_trips[['route_short_name', 'route_type', 'route_color', 'geometry']]
# ----> 2 gdf_trips.dissolve('route_short_name')
#
# ~\.conda\envs\mynewenv\lib\site-packages\geopandas\geodataframe.py in dissolve(self, by, aggfunc, as_index)
#     957
#     958         g = self.groupby(by=by, group_keys=False)[self.geometry.name].agg(
# --> 959             merge_geometries
#     960         )
#     961
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     257
#     258             try:
# --> 259                 return self._python_agg_general(func, *args, **kwargs)
#     260             except (ValueError, KeyError):
#     261                 # TODO: KeyError is raised in _python_agg_general,
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1171             try:
#    1172                 # if this function is invalid for this dtype, we will ignore it.
# -> 1173                 result, counts = self.grouper.agg_series(obj, f)
#    1174             except TypeError:
#    1175                 continue
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     697             # In the datetime64tz case it would incorrectly cast to tz-naive
#     698             # TODO: can we get a performant workaround for EAs backed by ndarray?
# --> 699             return self._aggregate_series_pure_python(obj, func)
#     700
#     701         elif obj.index._has_complex_internals:
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     747             # Each step of this loop corresponds to
#     748             #  libreduction._BaseGrouper._apply_to_group
# --> 749             res = func(group)
#     750             res = libreduction.extract_result(res)
#     751
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1158     def _python_agg_general(self, func, *args, **kwargs):
#    1159         func = self._is_builtin_func(func)
# -> 1160         f = lambda x: func(x, *args, **kwargs)
#    1161
#    1162         # iterate through "columns" ex exclusions to populate output dict
#
# ~\.conda\envs\mynewenv\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#     953         # Process spatial component
#     954         def merge_geometries(block):
# --> 955             merged_geom = block.unary_union
#     956             return merged_geom
#     957
#
# ~\.conda\envs\mynewenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# ~\.conda\envs\mynewenv\lib\site-packages\geopandas\base.py in unary_union(self)
#     302         """Returns a geometry containing the union of all geometries in the
#     303         ``GeoSeries``."""
# --> 304         return self.geometry.values.unary_union()
#     305
#     306     #
#
# ~\.conda\envs\mynewenv\lib\site-packages\geopandas\array.py in unary_union(self)
#     610
#     611     def unary_union(self):
# --> 612         return vectorized.unary_union(self.data)
#     613
#     614     #
#
# ~\.conda\envs\mynewenv\lib\site-packages\geopandas\_vectorized.py in unary_union(data)
#     828         return _pygeos_to_shapely(pygeos.union_all(data))
#     829     else:
# --> 830         return shapely.ops.unary_union(data)
#     831
#     832
#
# ~\.conda\envs\mynewenv\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     148         subs = (c_void_p * L)()
#     149         for i, g in enumerate(geoms):
# --> 150             subs[i] = g._geom
#     151         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
#     152         return geom_factory(lgeos.methods['unary_union'](collection))
#
# AttributeError: 'NoneType' object has no attribute '_geom'

# %%
gdf_lines = gdf_trips.dissolve('route_short_name')
# Out:
#       route_short_name  route_type route_color geometry
# 17832               S8           2      8f908f     None
# 17833               S8           2      8f908f     None
# 17834               S8           2      8f908f     None
# 17885               S8           2      8f908f     None
# 17886               S8           2      8f908f     None
# 17887               S8           2      8f908f     None
# 17888               S8           2      8f908f     None
# 17939               S8           2      8f908f     None
# 18092              RE8           2      8f908f     None
# 18093              RE8           2      8f908f     None
# 18094              RE8           2      8f908f     None
# 18095              RE8           2      8f908f     None
# 18096              RE8           2      8f908f     None
# 18097              RE8           2      8f908f     None
# 18098              RE8           2      8f908f     None
# 18099              RE8           2      8f908f     None
# 18100              RE8           2      8f908f     None
# 18151              RE8           2      8f908f     None
# 18152              RE8           2      8f908f     None
# 18153              RE8           2      8f908f     None
# 18193              RE8           2      8f908f     None
# 18194              RE8           2      8f908f     None
# 18195              RE8           2      8f908f     None
# 18264              RE8           2      8f908f     None
# 18265              RE8           2      8f908f     None
# 18266              RE8           2      8f908f     None
# 18267              RE8           2      8f908f     None
# 18268              RE8           2      8f908f     None
# 18269              RE8           2      8f908f     None
# 18343              RE8           2      8f908f     None
# 18344              RE8           2      8f908f     None
# 18345              RE8           2      8f908f     None
# 18346              RE8           2      8f908f     None
# 18347              RE8           2      8f908f     None
# 18348              RE8           2      8f908f     None
# 18393              RE8           2      8f908f     None
# 18394              RE8           2      8f908f     None
# 18395              RE8           2      8f908f     None
# 18480              RE8           2      8f908f     None
# 18481              RE8           2      8f908f     None
# 18482              RE8           2      8f908f     None
# 18483              RE8           2      8f908f     None
# 18484              RE8           2      8f908f     None
# 18485              RE8           2      8f908f     None
# 18486              RE8           2      8f908f     None
# 18487              RE8           2      8f908f     None
# 18488              RE8           2      8f908f     None
# 18637             RE90           2      8f908f     None
# 18648             RE90           2      8f908f     None
# 18682             RE90           2      8f908f     None
# 18684             RE90           2      8f908f     None
# 53459              161           3      FF0000     None

# %%
gdf_lines.head(3)
