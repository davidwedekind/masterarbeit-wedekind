# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
from sqlalchemy import create_engine
import requests
import json
from utils import load_db_parameters
import numpy as np

# %%
import logging
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

# %% [markdown]
# ## Read-In data from postgres db

# %%
db_uri = "postgres+psycopg2://postgres:dW49t8@0DPA2@localhost:5432/stuttgart_10pct_calibration"

# %%
engine = create_engine(db_uri, echo=False)

# %%
run_name = "cal_12_02"
query = f'''
        SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = '{run_name}' ;
            '''
print(query)
# Out:
#         SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = 'cal_12_02' ;

# %%
gdf_car_legs = gpd.read_postgis(
    sql=query,
    con=db_uri,
    geom_col="geometry",
    crs="epsg:25832"
)

# %%
gdf_car_legs.head(3)
# Out:
#    index       person        trip_id  dep_time  trav_time  wait_time  \
# 0   1275  70173005_60  70173005_60_1     30739        589          0
# 1   1647   70173015_3   70173015_3_2     24610        175          0
# 2   1650   70173015_3   70173015_3_3     51494        250          0
#
#    distance mode start_link        start_x  ...  access_stop_id  \
# 0      5092  car   65135327  513142.456880  ...            None
# 1      1544  car   73826175  512901.971817  ...            None
# 2      2180  car  104983867  512195.518749  ...            None
#
#   egress_stop_id  transit_line  transit_route  \
# 0           None          None           None
# 1           None          None           None
# 2           None          None           None
#
#                                             geometry arr_time  leg_speed  \
# 0  LINESTRING (513142.457 5402180.708, 515859.769...    31328  31.122581
# 1  LINESTRING (512901.972 5403555.623, 512195.519...    24785  31.762286
# 2  LINESTRING (512195.519 5403087.975, 513235.526...    51744  31.392000
#
#   pt_line pt_group   run_name
# 0    None     None  cal_12_02
# 1    None     None  cal_12_02
# 2    None     None  cal_12_02
#
# [3 rows x 24 columns]

# %%
gdf_car_legs.shape[0]
# Out:
# 104037

# %% [markdown]
# ## Create 10 % Sample

# %%
frac = 0.1

# %%
gdf_car_legs.columns
# Out:
# Index(['index', 'person', 'trip_id', 'dep_time', 'trav_time', 'wait_time',
#        'distance', 'mode', 'start_link', 'start_x', 'start_y', 'end_link',
#        'end_x', 'end_y', 'access_stop_id', 'egress_stop_id', 'transit_line',
#        'transit_route', 'geometry', 'arr_time', 'leg_speed', 'pt_line',
#        'pt_group', 'run_name'],
#       dtype='object')

# %%
gdf_car_legs_sample = gdf_car_legs[['person', 'trip_id', 'mode', 'dep_time', 'arr_time', 'trav_time', 'distance', 'start_link', 'end_link', 'geometry']].sample(frac=frac)
gdf_car_legs_sample.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                                 geometry
# 92262  LINESTRING (522279.826 5398387.263, 524217.047...
# 86864  LINESTRING (511967.303 5402635.837, 527870.249...
# 70961  LINESTRING (500883.471 5404681.276, 502939.259...

# %%
gdf_car_legs_sample.shape[0]
# Out:
# 10404

# %% [markdown]
# ## Bring to Here API format

# %%
gdf_car_legs_sample.to_crs("EPSG:4326", inplace=True)

# %% [markdown]
# **Coordinates**

# %%
def return_coord_values(s):
    s["start_x"] = (s['geometry']).coords[0][0]
    s["start_y"] = (s['geometry']).coords[0][1]
    s["end_x"] = (s['geometry']).coords[1][0]
    s["end_y"] = (s['geometry']).coords[1][1]
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(return_coord_values, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                               geometry   start_x    start_y  \
# 92262  LINESTRING (9.30302 48.73811, 9.32933 48.73113)  9.303023  48.738106
# 86864  LINESTRING (9.16289 48.77661, 9.37895 48.72385)  9.162889  48.776610
# 70961  LINESTRING (9.01203 48.79512, 9.04006 48.83786)  9.012029  48.795125
#
#           end_x      end_y
# 92262  9.329325  48.731130
# 86864  9.378950  48.723847
# 70961  9.040056  48.837856

# %% [markdown]
# **Times and Dates**

# %%
date = "2021-07-06"

# %%
def return_here_format_timestamp(time, date):
    hours = (time//3600)%24
    minutes = (time%3600)//60
    seconds = (time%3600)%60
    return date + "T" + str(hours).zfill(2) + ":" + str(minutes).zfill(2) + ":" + str(seconds).zfill(2)

# %%
gdf_car_legs_sample['dep_time_here_format'] = gdf_car_legs_sample['dep_time'].apply(lambda x: return_here_format_timestamp(x, date))

# %% [markdown]
# **API REQUEST STRINGS**

# %%
def build_here_url(apiKey, departure, origin, destination):
    
    BASE_URL_HERE = 'https://router.hereapi.com/v8/routes'
    routingMode = 'fast'
    mode = 'car'
    alternatives = 0
    
    return f'{BASE_URL_HERE}?&apiKey={apiKey}&origin={origin}&destination={destination}&departure={departure}&transportMode={mode}&routingMode={routingMode}&alternatives={alternatives}&return=summary'

# %%
apiKey = "_W_I-ts4uhv5x7PGfNTjIJlpr7nQyvw8dbvQ_vP3QV4"

# %%
gdf_car_legs_sample['api_request_string'] = gdf_car_legs_sample.apply(lambda x: build_here_url(
    apiKey,
    x['dep_time_here_format'],
    str(x['start_y']) + "," + str(x['start_x']),
    str(x['end_y']) + "," + str(x['end_x'])),axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                               geometry   start_x    start_y  \
# 92262  LINESTRING (9.30302 48.73811, 9.32933 48.73113)  9.303023  48.738106
# 86864  LINESTRING (9.16289 48.77661, 9.37895 48.72385)  9.162889  48.776610
# 70961  LINESTRING (9.01203 48.79512, 9.04006 48.83786)  9.012029  48.795125
#
#           end_x      end_y dep_time_here_format  \
# 92262  9.329325  48.731130  2021-07-06T13:34:02
# 86864  9.378950  48.723847  2021-07-06T15:49:17
# 70961  9.040056  48.837856  2021-07-06T19:38:33
#
#                                       api_request_string
# 92262  https://router.hereapi.com/v8/routes?&apiKey=_...
# 86864  https://router.hereapi.com/v8/routes?&apiKey=_...
# 70961  https://router.hereapi.com/v8/routes?&apiKey=_...

# %% [markdown]
# ## Process requests

# %%
size = gdf_car_legs_sample.shape[0]
count = 1
 
for index,row in gdf_car_legs_sample.iterrows():
    
    req = requests.get(row['api_request_string'])
    gdf_car_legs_sample.loc[index, 'req_answer']=req.text
    log_condition = (count%100==0) or (count==1) or (count==size)
        
    if (req.status_code != 200):
        print('Request with bad resonse: ' + str(req.status_code))
        print(row['api_request_string'])
        
    if (log_condition):
        print('No of requests processed: ' + str(count))
        
    count = count + 1
# Out:
# No of requests processed: 1
# No of requests processed: 100
# No of requests processed: 200
# No of requests processed: 300
# No of requests processed: 400
# No of requests processed: 500
# No of requests processed: 600
# No of requests processed: 700
# No of requests processed: 800
# No of requests processed: 900
# No of requests processed: 1000
# No of requests processed: 1100
# No of requests processed: 1200
# No of requests processed: 1300
# No of requests processed: 1400
# No of requests processed: 1500
# No of requests processed: 1600
# No of requests processed: 1700
# No of requests processed: 1800
# No of requests processed: 1900
# No of requests processed: 2000
# No of requests processed: 2100
# No of requests processed: 2200
# No of requests processed: 2300
# No of requests processed: 2400
# No of requests processed: 2500
# No of requests processed: 2600
# No of requests processed: 2700
# No of requests processed: 2800
# No of requests processed: 2900
# No of requests processed: 3000
# No of requests processed: 3100
# No of requests processed: 3200
# No of requests processed: 3300
# No of requests processed: 3400
# No of requests processed: 3500
# No of requests processed: 3600
# No of requests processed: 3700
# No of requests processed: 3800
# No of requests processed: 3900
# No of requests processed: 4000
# No of requests processed: 4100
# No of requests processed: 4200
# No of requests processed: 4300
# No of requests processed: 4400
# No of requests processed: 4500
# No of requests processed: 4600
# No of requests processed: 4700
# No of requests processed: 4800
# No of requests processed: 4900
# No of requests processed: 5000
# No of requests processed: 5100
# No of requests processed: 5200
# No of requests processed: 5300
# No of requests processed: 5400
# No of requests processed: 5500
# No of requests processed: 5600
# No of requests processed: 5700
# No of requests processed: 5800
# No of requests processed: 5900
# No of requests processed: 6000
# No of requests processed: 6100
# Request with bad resonse: 429
# https://router.hereapi.com/v8/routes?&apiKey=_W_I-ts4uhv5x7PGfNTjIJlpr7nQyvw8dbvQ_vP3QV4&origin=48.706473171710876,9.141315748794018&destination=48.684256623376896,9.16590206221115&departure=2021-07-06T11:48:19&transportMode=car&routingMode=fast&alternatives=0&return=summary
# No of requests processed: 6200
# No of requests processed: 6300
# No of requests processed: 6400
# No of requests processed: 6500
# No of requests processed: 6600
# No of requests processed: 6700
# No of requests processed: 6800
# No of requests processed: 6900
# No of requests processed: 7000
# No of requests processed: 7100
# No of requests processed: 7200
# No of requests processed: 7300
# No of requests processed: 7400
# No of requests processed: 7500
# No of requests processed: 7600
# No of requests processed: 7700
# No of requests processed: 7800
# No of requests processed: 7900
# No of requests processed: 8000
# No of requests processed: 8100
# No of requests processed: 8200
# No of requests processed: 8300
# No of requests processed: 8400
# No of requests processed: 8500
# No of requests processed: 8600
# No of requests processed: 8700
# No of requests processed: 8800
# No of requests processed: 8900
# No of requests processed: 9000
# No of requests processed: 9100
# No of requests processed: 9200
# No of requests processed: 9300
# No of requests processed: 9400
# No of requests processed: 9500
# No of requests processed: 9600
# No of requests processed: 9700
# No of requests processed: 9800
# No of requests processed: 9900
# No of requests processed: 10000
# No of requests processed: 10100
# No of requests processed: 10200
# No of requests processed: 10300
# No of requests processed: 10400
# No of requests processed: 10404

# %%
gdf_car_legs_sample.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                               geometry   start_x    start_y  \
# 92262  LINESTRING (9.30302 48.73811, 9.32933 48.73113)  9.303023  48.738106
# 86864  LINESTRING (9.16289 48.77661, 9.37895 48.72385)  9.162889  48.776610
# 70961  LINESTRING (9.01203 48.79512, 9.04006 48.83786)  9.012029  48.795125
#
#           end_x      end_y dep_time_here_format  \
# 92262  9.329325  48.731130  2021-07-06T13:34:02
# 86864  9.378950  48.723847  2021-07-06T15:49:17
# 70961  9.040056  48.837856  2021-07-06T19:38:33
#
#                                       api_request_string  \
# 92262  https://router.hereapi.com/v8/routes?&apiKey=_...
# 86864  https://router.hereapi.com/v8/routes?&apiKey=_...
# 70961  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer
# 92262  {"routes":[{"id":"f89978d5-d572-4bad-9917-9d39...
# 86864  {"routes":[{"id":"1dcf0547-82bd-4342-9724-2b18...
# 70961  {"routes":[{"id":"5ec5752d-a404-4692-99de-999f...

# %% [markdown]
# ## Process results

# %%
def extract_relevant_results(s):
    json_answ = json.loads(s['req_answer'])
    try:
        s['here_duration'] = json_answ['routes'][0]['sections'][0]['summary']['duration']
        s['here_baseDuration'] = json_answ['routes'][0]['sections'][0]['summary']['baseDuration']
        s['here_length'] = json_answ['routes'][0]['sections'][0]['summary']['length']
        
    except KeyError:
        s['here_duration'] = np.nan
        s['here_baseDuration'] = np.nan
        s['here_length'] = np.nan
        
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(extract_relevant_results, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                               geometry   start_x    start_y  \
# 92262  LINESTRING (9.30302 48.73811, 9.32933 48.73113)  9.303023  48.738106
# 86864  LINESTRING (9.16289 48.77661, 9.37895 48.72385)  9.162889  48.776610
# 70961  LINESTRING (9.01203 48.79512, 9.04006 48.83786)  9.012029  48.795125
#
#           end_x      end_y dep_time_here_format  \
# 92262  9.329325  48.731130  2021-07-06T13:34:02
# 86864  9.378950  48.723847  2021-07-06T15:49:17
# 70961  9.040056  48.837856  2021-07-06T19:38:33
#
#                                       api_request_string  \
# 92262  https://router.hereapi.com/v8/routes?&apiKey=_...
# 86864  https://router.hereapi.com/v8/routes?&apiKey=_...
# 70961  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer  here_duration  \
# 92262  {"routes":[{"id":"f89978d5-d572-4bad-9917-9d39...          217.0
# 86864  {"routes":[{"id":"1dcf0547-82bd-4342-9724-2b18...         1610.0
# 70961  {"routes":[{"id":"5ec5752d-a404-4692-99de-999f...          704.0
#
#        here_baseDuration  here_length
# 92262              220.0       2341.0
# 86864             1591.0      23940.0
# 70961              601.0       8261.0

# %%
gdf_car_legs_sample['here_duration'].isnull().sum()
# Out:
# 1

# %%
gdf_car_legs_sample_wna = gdf_car_legs_sample.dropna(subset=['here_duration'])

# %% [markdown]
# ## Statistics

# %%
gdf_car_legs_sample_wna['matsim_here_duration_ratio'] = gdf_car_legs_sample_wna['trav_time']/gdf_car_legs_sample_wna['here_duration']
gdf_car_legs_sample_wna['matsim_here_distance_ratio'] = gdf_car_legs_sample_wna['distance']/gdf_car_legs_sample_wna['here_length']
# Out:
# C:\Users\david\.conda\envs\mynewenv\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
gdf_car_legs_sample_wna.head(3)
# Out:
#              person         trip_id mode  dep_time  arr_time  trav_time  \
# 92262  73732085_148  73732085_148_4  car     48842     49246        404
# 86864  73257005_742  73257005_742_2  car     56957     59234       2277
# 70961  71229100_778  71229100_778_3  car     70713     71481        768
#
#        distance start_link  end_link  \
# 92262      2602   81542888  82614838
# 86864     20996  110265070  11991579
# 70961      7069   98378679    434486
#
#                                               geometry  ...     end_x  \
# 92262  LINESTRING (9.30302 48.73811, 9.32933 48.73113)  ...  9.329325
# 86864  LINESTRING (9.16289 48.77661, 9.37895 48.72385)  ...  9.378950
# 70961  LINESTRING (9.01203 48.79512, 9.04006 48.83786)  ...  9.040056
#
#            end_y  dep_time_here_format  \
# 92262  48.731130   2021-07-06T13:34:02
# 86864  48.723847   2021-07-06T15:49:17
# 70961  48.837856   2021-07-06T19:38:33
#
#                                       api_request_string  \
# 92262  https://router.hereapi.com/v8/routes?&apiKey=_...
# 86864  https://router.hereapi.com/v8/routes?&apiKey=_...
# 70961  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer here_duration  \
# 92262  {"routes":[{"id":"f89978d5-d572-4bad-9917-9d39...         217.0
# 86864  {"routes":[{"id":"1dcf0547-82bd-4342-9724-2b18...        1610.0
# 70961  {"routes":[{"id":"5ec5752d-a404-4692-99de-999f...         704.0
#
#       here_baseDuration  here_length  matsim_here_duration_ratio  \
# 92262             220.0       2341.0                    1.861751
# 86864            1591.0      23940.0                    1.414286
# 70961             601.0       8261.0                    1.090909
#
#        matsim_here_distance_ratio
# 92262                    1.111491
# 86864                    0.877026
# 70961                    0.855708
#
# [3 rows x 22 columns]

# %%
gdf_car_legs_sample_wna.boxplot(column='matsim_here_duration_ratio')
# Out:
# 2021-06-27 00:57:58,738 - DEBUG: CONFIGDIR=C:\Users\david\.matplotlib
# 2021-06-27 00:57:58,739 - DEBUG: (private) matplotlib data path: C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data
# 2021-06-27 00:57:58,742 - DEBUG: matplotlib data path: C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data
# 2021-06-27 00:57:58,742 - DEBUG: loaded rc file C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 2021-06-27 00:57:58,744 - DEBUG: matplotlib version 3.2.2
# 2021-06-27 00:57:58,745 - DEBUG: interactive is False
# 2021-06-27 00:57:58,745 - DEBUG: platform is win32
# 2021-06-27 00:57:58,745 - DEBUG: loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp65001', 'functools', '_functools', 'collections', '_collections_abc', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'mpl_toolkits', 'google', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'ast', '_ast', 'inspect', 'dis', 'opcode', '_opcode', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'pprint', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'locale', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'platform', 'ipython_genutils.text', 'textwrap', 'IPython.core.crashhandler', 'IPython.core.ultratb', 'pydoc', 'sysconfig', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'struct', '_struct', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'typing', 'typing.io', 'typing.re', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'decorator' ...
# 2021-06-27 00:57:58,785 - DEBUG: CACHEDIR=C:\Users\david\.matplotlib
# 2021-06-27 00:57:58,788 - DEBUG: Using fontManager instance from C:\Users\david\.matplotlib\fontlist-v310.json
# 2021-06-27 00:57:58,939 - DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2021-06-27 00:57:58,940 - DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2021-06-27 00:57:58,976 - DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2021-06-27 00:57:58,977 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,978 - DEBUG: findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,978 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2021-06-27 00:57:58,979 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,979 - DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,979 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,980 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,980 - DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,980 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,981 - DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,982 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2021-06-27 00:57:58,982 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,982 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,983 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,983 - DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,984 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,984 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,984 - DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,985 - DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,985 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,985 - DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,986 - DEBUG: findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,986 - DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,986 - DEBUG: findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,987 - DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,987 - DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,987 - DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,987 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,988 - DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,988 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,988 - DEBUG: findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,988 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,989 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2021-06-27 00:57:58,989 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,989 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2021-06-27 00:57:58,990 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,990 - DEBUG: findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,990 - DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,991 - DEBUG: findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,991 - DEBUG: findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,991 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,991 - DEBUG: findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,992 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,992 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,992 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,992 - DEBUG: findfont: score(<Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,993 - DEBUG: findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,993 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,993 - DEBUG: findfont: score(<Font 'Times New Roman' (timesbd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,994 - DEBUG: findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,994 - DEBUG: findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2021-06-27 00:57:58,994 - DEBUG: findfont: score(<Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,994 - DEBUG: findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,995 - DEBUG: findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,995 - DEBUG: findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,995 - DEBUG: findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,995 - DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:58,996 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:58,996 - DEBUG: findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:58,996 - DEBUG: findfont: score(<Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,997 - DEBUG: findfont: score(<Font 'Constantia' (constanb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:58,997 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,997 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:58,997 - DEBUG: findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,998 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:58,998 - DEBUG: findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,999 - DEBUG: findfont: score(<Font 'Constantia' (constanz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:58,999 - DEBUG: findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:58,999 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal semibold normal>) = 11.24
# 2021-06-27 00:57:59,000 - DEBUG: findfont: score(<Font 'Perpetua' (PER_____.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,000 - DEBUG: findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,000 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,000 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,001 - DEBUG: findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2021-06-27 00:57:59,001 - DEBUG: findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,001 - DEBUG: findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,002 - DEBUG: findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2021-06-27 00:57:59,002 - DEBUG: findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,002 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,003 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,003 - DEBUG: findfont: score(<Font 'Candara' (Candaral.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,003 - DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,003 - DEBUG: findfont: score(<Font 'Segoe Print' (segoeprb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,004 - DEBUG: findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2021-06-27 00:57:59,004 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,004 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,005 - DEBUG: findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 expanded>) = 10.25
# 2021-06-27 00:57:59,005 - DEBUG: findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal black normal>) = 10.525
# 2021-06-27 00:57:59,005 - DEBUG: findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,006 - DEBUG: findfont: score(<Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,006 - DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,006 - DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,006 - DEBUG: findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,007 - DEBUG: findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,007 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framdit.ttf) italic normal medium normal>) = 11.145
# 2021-06-27 00:57:59,007 - DEBUG: findfont: score(<Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,008 - DEBUG: findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,008 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal black normal>) = 10.525
# 2021-06-27 00:57:59,008 - DEBUG: findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,008 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,009 - DEBUG: findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,009 - DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,009 - DEBUG: findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,010 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:59,010 - DEBUG: findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,010 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSDI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,010 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,011 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,011 - DEBUG: findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,011 - DEBUG: findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,012 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,012 - DEBUG: findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,012 - DEBUG: findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,012 - DEBUG: findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,013 - DEBUG: findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,013 - DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal heavy normal>) = 11.43
# 2021-06-27 00:57:59,013 - DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,014 - DEBUG: findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,014 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKI.TTF) italic normal book normal>) = 11.05
# 2021-06-27 00:57:59,014 - DEBUG: findfont: score(<Font 'Elephant' (ELEPHNTI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,015 - DEBUG: findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,015 - DEBUG: findfont: score(<Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,015 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,016 - DEBUG: findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,016 - DEBUG: findfont: score(<Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,016 - DEBUG: findfont: score(<Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,017 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,017 - DEBUG: findfont: score(<Font 'Corbel' (corbell.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,017 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,017 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,018 - DEBUG: findfont: score(<Font 'Book Antiqua' (BKANT.TTF) normal normal book normal>) = 10.05
# 2021-06-27 00:57:59,018 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,018 - DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal bold condensed>) = 10.535
# 2021-06-27 00:57:59,018 - DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,019 - DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABKIT.TTF) italic normal book normal>) = 11.05
# 2021-06-27 00:57:59,019 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEDI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,019 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,020 - DEBUG: findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,020 - DEBUG: findfont: score(<Font 'Candara' (Candarali.ttf) italic normal light normal>) = 11.24
# 2021-06-27 00:57:59,020 - DEBUG: findfont: score(<Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,020 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSD.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,021 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,021 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,021 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,022 - DEBUG: findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,022 - DEBUG: findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,022 - DEBUG: findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,023 - DEBUG: findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,023 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,023 - DEBUG: findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,024 - DEBUG: findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,024 - DEBUG: findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,024 - DEBUG: findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,024 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,025 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,025 - DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
# 2021-06-27 00:57:59,025 - DEBUG: findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,026 - DEBUG: findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,026 - DEBUG: findfont: score(<Font 'Colonna MT' (COLONNA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,026 - DEBUG: findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,027 - DEBUG: findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,027 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal semibold normal>) = 10.24
# 2021-06-27 00:57:59,027 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,028 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,028 - DEBUG: findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,028 - DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWAD.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,028 - DEBUG: findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,029 - DEBUG: findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,029 - DEBUG: findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,029 - DEBUG: findfont: score(<Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,030 - DEBUG: findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,030 - DEBUG: findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,030 - DEBUG: findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,030 - DEBUG: findfont: score(<Font 'Palace Script MT' (PALSCRI.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,031 - DEBUG: findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,031 - DEBUG: findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,031 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comicz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,032 - DEBUG: findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2021-06-27 00:57:59,032 - DEBUG: findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal light normal>) = 11.24
# 2021-06-27 00:57:59,033 - DEBUG: findfont: score(<Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,033 - DEBUG: findfont: score(<Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,033 - DEBUG: findfont: score(<Font 'Symbol' (symbol.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,034 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,034 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,034 - DEBUG: findfont: score(<Font 'Algerian' (ALGER.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,034 - DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,035 - DEBUG: findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,035 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,035 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,036 - DEBUG: findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,036 - DEBUG: findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal medium normal>) = 10.145
# 2021-06-27 00:57:59,036 - DEBUG: findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,037 - DEBUG: findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,037 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,037 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal book normal>) = 11.05
# 2021-06-27 00:57:59,037 - DEBUG: findfont: score(<Font 'MS Outlook' (OUTLOOK.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,038 - DEBUG: findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal black normal>) = 10.525
# 2021-06-27 00:57:59,038 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal demi condensed>) = 10.44
# 2021-06-27 00:57:59,038 - DEBUG: findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,039 - DEBUG: findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,039 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,039 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,040 - DEBUG: findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2021-06-27 00:57:59,040 - DEBUG: findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,040 - DEBUG: findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,041 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,041 - DEBUG: findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,041 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,042 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal medium normal>) = 10.145
# 2021-06-27 00:57:59,042 - DEBUG: findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,042 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,043 - DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,043 - DEBUG: findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,043 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,044 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAI.TTF) italic normal black normal>) = 11.525
# 2021-06-27 00:57:59,044 - DEBUG: findfont: score(<Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,044 - DEBUG: findfont: score(<Font 'TeamViewer15' (teamviewer15.otf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,044 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILB____.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,045 - DEBUG: findfont: score(<Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,046 - DEBUG: findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,046 - DEBUG: findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,047 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,047 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXD.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,047 - DEBUG: findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,048 - DEBUG: findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,048 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,049 - DEBUG: findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,049 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,049 - DEBUG: findfont: score(<Font 'Arial' (ariblk.ttf) normal normal black normal>) = 6.888636363636364
# 2021-06-27 00:57:59,050 - DEBUG: findfont: score(<Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal black normal>) = 10.525
# 2021-06-27 00:57:59,050 - DEBUG: findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,050 - DEBUG: findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,051 - DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,051 - DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWDB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,051 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,052 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,052 - DEBUG: findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,052 - DEBUG: findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,053 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,053 - DEBUG: findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,053 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,054 - DEBUG: findfont: score(<Font 'Agency FB' (AGENCYB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,054 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,054 - DEBUG: findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal light normal>) = 11.24
# 2021-06-27 00:57:59,055 - DEBUG: findfont: score(<Font 'Ravie' (RAVIE.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,055 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKBI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,055 - DEBUG: findfont: score(<Font 'Kristen ITC' (ITCKRIST.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,056 - DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,056 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal book normal>) = 10.05
# 2021-06-27 00:57:59,056 - DEBUG: findfont: score(<Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,056 - DEBUG: findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:59,057 - DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABK.TTF) normal normal book normal>) = 10.05
# 2021-06-27 00:57:59,057 - DEBUG: findfont: score(<Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,057 - DEBUG: findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,058 - DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal heavy normal>) = 10.43
# 2021-06-27 00:57:59,058 - DEBUG: findfont: score(<Font 'Rage Italic' (RAGE.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,058 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CB.TTF) normal normal 700 condensed>) = 10.535
# 2021-06-27 00:57:59,058 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,059 - DEBUG: findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,059 - DEBUG: findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,059 - DEBUG: findfont: score(<Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,059 - DEBUG: findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:59,060 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,060 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,060 - DEBUG: findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,061 - DEBUG: findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,061 - DEBUG: findfont: score(<Font 'Perpetua' (PERI____.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,062 - DEBUG: findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,062 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,062 - DEBUG: findfont: score(<Font 'Bradley Hand ITC' (BRADHITC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,063 - DEBUG: findfont: score(<Font 'Centaur' (CENTAUR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,063 - DEBUG: findfont: score(<Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,063 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,063 - DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,064 - DEBUG: findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,064 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,064 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal demi normal>) = 11.24
# 2021-06-27 00:57:59,065 - DEBUG: findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,065 - DEBUG: findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,065 - DEBUG: findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,066 - DEBUG: findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2021-06-27 00:57:59,066 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,066 - DEBUG: findfont: score(<Font 'Felix Titling' (FELIXTI.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,067 - DEBUG: findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,067 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,067 - DEBUG: findfont: score(<Font 'Informal Roman' (INFROMAN.TTF) normal normal roman normal>) = 10.145
# 2021-06-27 00:57:59,067 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,068 - DEBUG: findfont: score(<Font 'Eras Bold ITC' (ERASBD.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,068 - DEBUG: findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,068 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal light normal>) = 11.24
# 2021-06-27 00:57:59,069 - DEBUG: findfont: score(<Font 'Forte' (FORTE.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,069 - DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERTI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,069 - DEBUG: findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,069 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILBI___.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,070 - DEBUG: findfont: score(<Font 'Berlin Sans FB Demi' (BRLNSDB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,070 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal bold condensed>) = 10.535
# 2021-06-27 00:57:59,070 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium Cond' (FRAMDCN.TTF) normal normal medium condensed>) = 10.344999999999999
# 2021-06-27 00:57:59,071 - DEBUG: findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,071 - DEBUG: findfont: score(<Font 'Onyx' (ONYX.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,071 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,071 - DEBUG: findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,072 - DEBUG: findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,072 - DEBUG: findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2021-06-27 00:57:59,072 - DEBUG: findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,073 - DEBUG: findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,073 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANS.TTF) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:59,073 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,073 - DEBUG: findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,074 - DEBUG: findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,074 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:59,074 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,075 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal 700 condensed>) = 10.535
# 2021-06-27 00:57:59,075 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal book normal>) = 11.05
# 2021-06-27 00:57:59,075 - DEBUG: findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 2021-06-27 00:57:59,075 - DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,076 - DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,076 - DEBUG: findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,076 - DEBUG: findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,077 - DEBUG: findfont: score(<Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,077 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,077 - DEBUG: findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,078 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,078 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,078 - DEBUG: findfont: score(<Font 'Jokerman' (JOKERMAN.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,078 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
# 2021-06-27 00:57:59,079 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,079 - DEBUG: findfont: score(<Font 'Times New Roman' (times.ttf) normal normal roman normal>) = 10.145
# 2021-06-27 00:57:59,079 - DEBUG: findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,080 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
# 2021-06-27 00:57:59,080 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPE.TTF) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:59,080 - DEBUG: findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,080 - DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,081 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCBI____.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,081 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,081 - DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,082 - DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,082 - DEBUG: findfont: score(<Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,082 - DEBUG: findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,083 - DEBUG: findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal book normal>) = 10.05
# 2021-06-27 00:57:59,083 - DEBUG: findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
# 2021-06-27 00:57:59,083 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal medium normal>) = 10.145
# 2021-06-27 00:57:59,084 - DEBUG: findfont: score(<Font 'Century Schoolbook' (CENSCBK.TTF) normal normal book normal>) = 10.05
# 2021-06-27 00:57:59,084 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAX.TTF) normal normal regular normal>) = 10.05
# 2021-06-27 00:57:59,084 - DEBUG: findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,084 - DEBUG: findfont: score(<Font 'Calibri' (calibril.ttf) normal normal light normal>) = 10.24
# 2021-06-27 00:57:59,085 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADM.TTF) normal normal demi normal>) = 10.24
# 2021-06-27 00:57:59,085 - DEBUG: findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,085 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,086 - DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,086 - DEBUG: findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,086 - DEBUG: findfont: score(<Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,087 - DEBUG: findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal demi normal>) = 10.24
# 2021-06-27 00:57:59,087 - DEBUG: findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,087 - DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,088 - DEBUG: findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal bold normal>) = 10.335
# 2021-06-27 00:57:59,088 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,088 - DEBUG: findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,088 - DEBUG: findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,089 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_B.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,089 - DEBUG: findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal light normal>) = 11.24
# 2021-06-27 00:57:59,089 - DEBUG: findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,090 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal medium normal>) = 10.145
# 2021-06-27 00:57:59,090 - DEBUG: findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2021-06-27 00:57:59,090 - DEBUG: findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,091 - DEBUG: findfont: score(<Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,091 - DEBUG: findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2021-06-27 00:57:59,091 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKBI.TTF) italic normal 700 normal>) = 11.335
# 2021-06-27 00:57:59,092 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
# 2021-06-27 00:57:59,092 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
# 2021-06-27 00:57:59,092 - DEBUG: findfont: score(<Font 'Consolas' (consola.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,092 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFB.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,093 - DEBUG: findfont: score(<Font 'Perpetua' (PERB____.TTF) normal normal 700 normal>) = 10.335
# 2021-06-27 00:57:59,093 - DEBUG: findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2021-06-27 00:57:59,093 - DEBUG: findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,094 - DEBUG: findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal roman normal>) = 11.145
# 2021-06-27 00:57:59,094 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
# 2021-06-27 00:57:59,094 - DEBUG: findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal black normal>) = 11.525
# 2021-06-27 00:57:59,094 - DEBUG: findfont: score(<Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal bold condensed>) = 10.535
# 2021-06-27 00:57:59,095 - DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\david\\.conda\\envs\\mynewenv\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %%
gdf_car_legs_sample_wna['matsim_here_duration_ratio'].mean()
# Out:
# inf

# %%
gdf_car_legs_sample_wna['matsim_here_duration_ratio'].median()
# Out:
# 1.2191616766467066

# %%
gdf_car_legs_sample_wna.to_csv("C:/Users/david/Desktop/car_routes_12_02.csv",index=False,mode='w')

# %%
cond = (gdf_car_legs_sample_wna['distance'] > 1000) & (gdf_car_legs_sample_wna['distance'] < 10000)

# %%
gdf_car_legs_sample_wna[cond]['matsim_here_duration_ratio'].mean()
# Out:
# 1.227912547324591

# %%
gdf_car_legs_sample_wna[cond]['matsim_here_duration_ratio'].median()
# Out:
# 1.1873802248817025
