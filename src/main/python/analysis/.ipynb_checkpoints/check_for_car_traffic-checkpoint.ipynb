# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
from sqlalchemy import create_engine
import requests
import json
from utils import load_db_parameters

# %%
import logging
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

# %% [markdown]
# ## Read-In data from postgres db

# %%
db_uri = "postgres+psycopg2://postgres:dW49t8@0DPA2@localhost:5432/stuttgart_10pct_calibration"

# %%
engine = create_engine(db_uri, echo=False)

# %%
run_name = "cal_149_04"
query = f'''
        SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = '{run_name}' ;
            '''
print(query)
# Out:
#         SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = 'cal_149_04' ;

# %%
gdf_car_legs = gpd.read_postgis(
    sql=query,
    con=db_uri,
    geom_col="geometry",
    crs="epsg:25832"
)

# %%
gdf_car_legs.head(3)
# Out:
#    index         person          trip_id  dep_time  trav_time  wait_time  \
# 0     86  68723080_1004  68723080_1004_4     49138        747          0
# 1     89  68723080_1004  68723080_1004_5     50577        266          0
# 2    156   68753020_716   68753020_716_5     40939        473          0
#
#    distance mode start_link        start_x  ...  access_stop_id  \
# 0      4765  car   65885791  520072.306792  ...            None
# 1      2259  car  109748144  517317.607179  ...            None
# 2      2738  car    5534903  513141.484779  ...            None
#
#   egress_stop_id  transit_line  transit_route  \
# 0           None          None           None
# 1           None          None           None
# 2           None          None           None
#
#                                             geometry arr_time  leg_speed  \
# 0  LINESTRING (520072.307 5400853.253, 517317.607...    49885  22.963855
# 1  LINESTRING (517317.607 5402747.264, 518588.822...    50843  30.572932
# 2  LINESTRING (513141.485 5412110.332, 511312.865...    41412  20.838901
#
#   pt_line pt_group    run_name
# 0    None     None  cal_149_04
# 1    None     None  cal_149_04
# 2    None     None  cal_149_04
#
# [3 rows x 24 columns]

# %%
gdf_car_legs.shape[0]
# Out:
# 104754

# %% [markdown]
# ## Create 1 % Sample

# %%
frac = 0.1

# %%
gdf_car_legs.columns
# Out:
# Index(['index', 'person', 'trip_id', 'dep_time', 'trav_time', 'wait_time',
#        'distance', 'mode', 'start_link', 'start_x', 'start_y', 'end_link',
#        'end_x', 'end_y', 'access_stop_id', 'egress_stop_id', 'transit_line',
#        'transit_route', 'geometry', 'arr_time', 'leg_speed', 'pt_line',
#        'pt_group', 'run_name'],
#       dtype='object')

# %%
gdf_car_legs_sample = gdf_car_legs[['person', 'trip_id', 'mode', 'dep_time', 'arr_time', 'trav_time', 'distance', 'start_link', 'end_link', 'geometry']].sample(frac=frac)
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                                 geometry
# 61403  LINESTRING (498258.135 5394462.026, 502288.432...
# 84775  LINESTRING (509352.733 5396913.950, 515560.073...
# 33745  LINESTRING (512674.493 5400535.181, 512949.861...

# %% [markdown]
# ## Bring to Here API format

# %%
gdf_car_legs_sample.to_crs("EPSG:4326", inplace=True)

# %% [markdown]
# **Coordinates**

# %%
def return_coord_values(s):
    s["start_x"] = (s['geometry']).coords[0][0]
    s["start_y"] = (s['geometry']).coords[0][1]
    s["end_x"] = (s['geometry']).coords[1][0]
    s["end_y"] = (s['geometry']).coords[1][1]
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(return_coord_values, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                               geometry   start_x    start_y  \
# 61403  LINESTRING (8.97633 48.70319, 9.03110 48.70586)  8.976326  48.703191
# 84775  LINESTRING (9.12717 48.72518, 9.21147 48.70103)  9.127172  48.725181
# 33745  LINESTRING (9.17245 48.75770, 9.17621 48.76197)  9.172450  48.757698
#
#           end_x      end_y
# 61403  9.031105  48.705861
# 84775  9.211474  48.701032
# 33745  9.176212  48.761972

# %% [markdown]
# **Times and Dates**

# %%
date = "2021-04-13"

# %%
def return_here_format_timestamp(time, date):
    hours = (time//3600)%24
    minutes = (time%3600)//60
    seconds = (time%3600)%60
    return date + "T" + str(hours).zfill(2) + ":" + str(minutes).zfill(2) + ":" + str(seconds).zfill(2)

# %%
gdf_car_legs_sample['dep_time_here_format'] = gdf_car_legs_sample['dep_time'].apply(lambda x: return_here_format_timestamp(x, date))

# %% [markdown]
# **API REQUEST STRINGS**

# %%
def build_here_url(apiKey, departure, origin, destination):
    
    BASE_URL_HERE = 'https://router.hereapi.com/v8/routes'
    routingMode = 'fast'
    mode = 'car'
    alternatives = 0
    
    return f'{BASE_URL_HERE}?&apiKey={apiKey}&origin={origin}&destination={destination}&departure={departure}&transportMode={mode}&routingMode={routingMode}&alternatives={alternatives}&return=summary'

# %%
apiKey = "_W_I-ts4uhv5x7PGfNTjIJlpr7nQyvw8dbvQ_vP3QV4"

# %%
gdf_car_legs_sample['api_request_string'] = gdf_car_legs_sample.apply(lambda x: build_here_url(
    apiKey,
    x['dep_time_here_format'],
    str(x['start_y']) + "," + str(x['start_x']),
    str(x['end_y']) + "," + str(x['end_x'])),axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                               geometry   start_x    start_y  \
# 61403  LINESTRING (8.97633 48.70319, 9.03110 48.70586)  8.976326  48.703191
# 84775  LINESTRING (9.12717 48.72518, 9.21147 48.70103)  9.127172  48.725181
# 33745  LINESTRING (9.17245 48.75770, 9.17621 48.76197)  9.172450  48.757698
#
#           end_x      end_y dep_time_here_format  \
# 61403  9.031105  48.705861  2021-04-13T17:00:01
# 84775  9.211474  48.701032  2021-04-13T08:40:55
# 33745  9.176212  48.761972  2021-04-13T23:21:22
#
#                                       api_request_string
# 61403  https://router.hereapi.com/v8/routes?&apiKey=_...
# 84775  https://router.hereapi.com/v8/routes?&apiKey=_...
# 33745  https://router.hereapi.com/v8/routes?&apiKey=_...

# %% [markdown]
# ## Process requests

# %%
size = gdf_car_legs_sample.shape[0]
count = 1
 
for index,row in gdf_car_legs_sample.iterrows():
    
    req = requests.get(row['api_request_string'])
    gdf_car_legs_sample.loc[index, 'req_answer']=req.text
    log_condition = (count%100==0) or (count==1) or (count==size)
        
    if (req.status_code != 200):
        print('Request with bad resonse: ' + str(req.status_code))
        print(row['api_request_string'])
        
    if (log_condition):
        print('No of requests processed: ' + str(count))
        
    count = count + 1
# Out:
# No of requests processed: 1
# No of requests processed: 100
# No of requests processed: 200
# No of requests processed: 300
# No of requests processed: 400
# No of requests processed: 500
# No of requests processed: 600
# No of requests processed: 700
# No of requests processed: 800
# No of requests processed: 900
# No of requests processed: 1000
# No of requests processed: 1100
# No of requests processed: 1200
# No of requests processed: 1300
# No of requests processed: 1400
# No of requests processed: 1500
# No of requests processed: 1600
# No of requests processed: 1700
# No of requests processed: 1800
# No of requests processed: 1900
# No of requests processed: 2000
# No of requests processed: 2100
# No of requests processed: 2200
# No of requests processed: 2300
# No of requests processed: 2400
# No of requests processed: 2500
# No of requests processed: 2600
# No of requests processed: 2700
# No of requests processed: 2800
# No of requests processed: 2900
# No of requests processed: 3000
# No of requests processed: 3100
# No of requests processed: 3200
# No of requests processed: 3300
# No of requests processed: 3400
# No of requests processed: 3500
# No of requests processed: 3600
# No of requests processed: 3700
# No of requests processed: 3800
# No of requests processed: 3900
# No of requests processed: 4000
# No of requests processed: 4100
# No of requests processed: 4200
# No of requests processed: 4300
# No of requests processed: 4400
# No of requests processed: 4500
# No of requests processed: 4600
# No of requests processed: 4700
# No of requests processed: 4800
# No of requests processed: 4900
# No of requests processed: 5000
# No of requests processed: 5100
# No of requests processed: 5200
# No of requests processed: 5300
# No of requests processed: 5400
# No of requests processed: 5500
# No of requests processed: 5600
# No of requests processed: 5700
# No of requests processed: 5800
# No of requests processed: 5900
# No of requests processed: 6000
# No of requests processed: 6100
# No of requests processed: 6200
# No of requests processed: 6300
# No of requests processed: 6400
# No of requests processed: 6500
# No of requests processed: 6600
# No of requests processed: 6700
# No of requests processed: 6800
# No of requests processed: 6900
# No of requests processed: 7000
# No of requests processed: 7100
# No of requests processed: 7200
# No of requests processed: 7300
# No of requests processed: 7400
# No of requests processed: 7500
# No of requests processed: 7600
# No of requests processed: 7700
# No of requests processed: 7800
# No of requests processed: 7900
# No of requests processed: 8000
# No of requests processed: 8100
# No of requests processed: 8200
# No of requests processed: 8300
# No of requests processed: 8400
# No of requests processed: 8500
# No of requests processed: 8600
# No of requests processed: 8700
# No of requests processed: 8800
# No of requests processed: 8900
# No of requests processed: 9000
# No of requests processed: 9100
# No of requests processed: 9200
# No of requests processed: 9300
# No of requests processed: 9400
# No of requests processed: 9500
# No of requests processed: 9600
# No of requests processed: 9700
# No of requests processed: 9800
# No of requests processed: 9900
# No of requests processed: 10000
# No of requests processed: 10100
# No of requests processed: 10200
# No of requests processed: 10300
# No of requests processed: 10400
# No of requests processed: 10475

# %%
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                               geometry   start_x    start_y  \
# 61403  LINESTRING (8.97633 48.70319, 9.03110 48.70586)  8.976326  48.703191
# 84775  LINESTRING (9.12717 48.72518, 9.21147 48.70103)  9.127172  48.725181
# 33745  LINESTRING (9.17245 48.75770, 9.17621 48.76197)  9.172450  48.757698
#
#           end_x      end_y dep_time_here_format  \
# 61403  9.031105  48.705861  2021-04-13T17:00:01
# 84775  9.211474  48.701032  2021-04-13T08:40:55
# 33745  9.176212  48.761972  2021-04-13T23:21:22
#
#                                       api_request_string  \
# 61403  https://router.hereapi.com/v8/routes?&apiKey=_...
# 84775  https://router.hereapi.com/v8/routes?&apiKey=_...
# 33745  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer
# 61403  {"routes":[{"id":"b20582b5-339e-46e3-b077-0015...
# 84775  {"routes":[{"id":"1d593f65-0e06-4aad-89fb-aef9...
# 33745  {"routes":[{"id":"e04f6db0-5819-48c5-b0d5-5fff...

# %% [markdown]
# ## Process results

# %%
def extract_relevant_results(s):
    json_answ = json.loads(s['req_answer'])
    s['here_duration'] = json_answ['routes'][0]['sections'][0]['summary']['duration']
    s['here_baseDuration'] = json_answ['routes'][0]['sections'][0]['summary']['baseDuration']
    s['here_length'] = json_answ['routes'][0]['sections'][0]['summary']['length']
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(extract_relevant_results, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                               geometry   start_x    start_y  \
# 61403  LINESTRING (8.97633 48.70319, 9.03110 48.70586)  8.976326  48.703191
# 84775  LINESTRING (9.12717 48.72518, 9.21147 48.70103)  9.127172  48.725181
# 33745  LINESTRING (9.17245 48.75770, 9.17621 48.76197)  9.172450  48.757698
#
#           end_x      end_y dep_time_here_format  \
# 61403  9.031105  48.705861  2021-04-13T17:00:01
# 84775  9.211474  48.701032  2021-04-13T08:40:55
# 33745  9.176212  48.761972  2021-04-13T23:21:22
#
#                                       api_request_string  \
# 61403  https://router.hereapi.com/v8/routes?&apiKey=_...
# 84775  https://router.hereapi.com/v8/routes?&apiKey=_...
# 33745  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer  here_duration  \
# 61403  {"routes":[{"id":"b20582b5-339e-46e3-b077-0015...            528
# 84775  {"routes":[{"id":"1d593f65-0e06-4aad-89fb-aef9...            745
# 33745  {"routes":[{"id":"e04f6db0-5819-48c5-b0d5-5fff...            288
#
#        here_baseDuration  here_length
# 61403                484         6347
# 84775                704         9105
# 33745                288         1654

# %% [markdown]
# ## Statistics

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'] = gdf_car_legs_sample['trav_time']/gdf_car_legs_sample['here_duration']
gdf_car_legs_sample['matsim_here_distance_ratio'] = gdf_car_legs_sample['distance']/gdf_car_legs_sample['here_length']

# %%
gdf_car_legs_sample.head(3)
# Out:
#               person          trip_id mode  dep_time  arr_time  trav_time  \
# 61403   71069025_108   71069025_108_2  car     61201     61764        563
# 84775  72762085_1785  72762085_1785_2  car     31255     32273       1018
# 33745   70599010_356   70599010_356_6  car     84082     84400        318
#
#        distance start_link   end_link  \
# 61403      5579   95934277  113819770
# 84775      8999  112641413    1123558
# 33745      1915   57732461    3926489
#
#                                               geometry  ...     end_x  \
# 61403  LINESTRING (8.97633 48.70319, 9.03110 48.70586)  ...  9.031105
# 84775  LINESTRING (9.12717 48.72518, 9.21147 48.70103)  ...  9.211474
# 33745  LINESTRING (9.17245 48.75770, 9.17621 48.76197)  ...  9.176212
#
#            end_y  dep_time_here_format  \
# 61403  48.705861   2021-04-13T17:00:01
# 84775  48.701032   2021-04-13T08:40:55
# 33745  48.761972   2021-04-13T23:21:22
#
#                                       api_request_string  \
# 61403  https://router.hereapi.com/v8/routes?&apiKey=_...
# 84775  https://router.hereapi.com/v8/routes?&apiKey=_...
# 33745  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                               req_answer here_duration  \
# 61403  {"routes":[{"id":"b20582b5-339e-46e3-b077-0015...           528
# 84775  {"routes":[{"id":"1d593f65-0e06-4aad-89fb-aef9...           745
# 33745  {"routes":[{"id":"e04f6db0-5819-48c5-b0d5-5fff...           288
#
#       here_baseDuration  here_length  matsim_here_duration_ratio  \
# 61403               484         6347                    1.066288
# 84775               704         9105                    1.366443
# 33745               288         1654                    1.104167
#
#        matsim_here_distance_ratio
# 61403                    0.878998
# 84775                    0.988358
# 33745                    1.157799
#
# [3 rows x 22 columns]

# %%
gdf_car_legs_sample.boxplot(column='matsim_here_duration_ratio')
# Out:
# 2021-03-21 11:59:04,850 - DEBUG: CONFIGDIR=C:\Users\david\.matplotlib
# 2021-03-21 11:59:04,851 - DEBUG: (private) matplotlib data path: C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data
# 2021-03-21 11:59:04,860 - DEBUG: matplotlib data path: C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data
# 2021-03-21 11:59:04,861 - DEBUG: loaded rc file C:\Users\david\.conda\envs\mynewenv\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 2021-03-21 11:59:04,863 - DEBUG: matplotlib version 3.2.2
# 2021-03-21 11:59:04,864 - DEBUG: interactive is False
# 2021-03-21 11:59:04,864 - DEBUG: platform is win32
# 2021-03-21 11:59:04,865 - DEBUG: loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp65001', 'functools', '_functools', 'collections', '_collections_abc', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'mpl_toolkits', 'google', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'ast', '_ast', 'inspect', 'dis', 'opcode', '_opcode', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'pprint', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'locale', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'platform', 'ipython_genutils.text', 'textwrap', 'IPython.core.crashhandler', 'IPython.core.ultratb', 'pydoc', 'sysconfig', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'struct', '_struct', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'typing', 'typing.io', 'typing.re', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'decorator' ...
# 2021-03-21 11:59:04,934 - DEBUG: CACHEDIR=C:\Users\david\.matplotlib
# 2021-03-21 11:59:04,943 - DEBUG: Using fontManager instance from C:\Users\david\.matplotlib\fontlist-v310.json
# 2021-03-21 11:59:05,189 - DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2021-03-21 11:59:05,190 - DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2021-03-21 11:59:05,275 - DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2021-03-21 11:59:05,275 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,276 - DEBUG: findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,276 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2021-03-21 11:59:05,277 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,277 - DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,278 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,278 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,278 - DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,279 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,279 - DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,279 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2021-03-21 11:59:05,280 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,280 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,280 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,281 - DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,281 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,281 - DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,282 - DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,282 - DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,282 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,283 - DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,283 - DEBUG: findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,284 - DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,284 - DEBUG: findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,284 - DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,285 - DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,285 - DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,285 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,286 - DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,286 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,287 - DEBUG: findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,287 - DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,287 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2021-03-21 11:59:05,288 - DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,288 - DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2021-03-21 11:59:05,288 - DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,289 - DEBUG: findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,289 - DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,289 - DEBUG: findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,290 - DEBUG: findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,290 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,290 - DEBUG: findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,291 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,291 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,291 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,292 - DEBUG: findfont: score(<Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,292 - DEBUG: findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,293 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,293 - DEBUG: findfont: score(<Font 'Times New Roman' (timesbd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,293 - DEBUG: findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,294 - DEBUG: findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2021-03-21 11:59:05,294 - DEBUG: findfont: score(<Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,294 - DEBUG: findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,295 - DEBUG: findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,295 - DEBUG: findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,295 - DEBUG: findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,296 - DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,296 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,296 - DEBUG: findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,296 - DEBUG: findfont: score(<Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,297 - DEBUG: findfont: score(<Font 'Constantia' (constanb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,297 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,297 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,298 - DEBUG: findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,298 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,298 - DEBUG: findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,299 - DEBUG: findfont: score(<Font 'Constantia' (constanz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,299 - DEBUG: findfont: score(<Font 'Engravers MT' (ENGR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,300 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal semibold normal>) = 11.24
# 2021-03-21 11:59:05,300 - DEBUG: findfont: score(<Font 'Perpetua' (PER_____.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,300 - DEBUG: findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,301 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,301 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,302 - DEBUG: findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2021-03-21 11:59:05,302 - DEBUG: findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,302 - DEBUG: findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,303 - DEBUG: findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2021-03-21 11:59:05,303 - DEBUG: findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,303 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,304 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,304 - DEBUG: findfont: score(<Font 'Candara' (Candaral.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,304 - DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,305 - DEBUG: findfont: score(<Font 'Segoe Print' (segoeprb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,305 - DEBUG: findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2021-03-21 11:59:05,305 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXDI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,306 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,306 - DEBUG: findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 expanded>) = 10.25
# 2021-03-21 11:59:05,306 - DEBUG: findfont: score(<Font 'Cooper Black' (COOPBL.TTF) normal normal black normal>) = 10.525
# 2021-03-21 11:59:05,307 - DEBUG: findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,307 - DEBUG: findfont: score(<Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,307 - DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,308 - DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,308 - DEBUG: findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,308 - DEBUG: findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,309 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framdit.ttf) italic normal medium normal>) = 11.145
# 2021-03-21 11:59:05,309 - DEBUG: findfont: score(<Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,309 - DEBUG: findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,310 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal black normal>) = 10.525
# 2021-03-21 11:59:05,310 - DEBUG: findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,310 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,311 - DEBUG: findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,311 - DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,311 - DEBUG: findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,312 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,312 - DEBUG: findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,312 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSDI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,313 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,313 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,313 - DEBUG: findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,313 - DEBUG: findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,314 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,314 - DEBUG: findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,314 - DEBUG: findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,315 - DEBUG: findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,315 - DEBUG: findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,315 - DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal heavy normal>) = 11.43
# 2021-03-21 11:59:05,316 - DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,316 - DEBUG: findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,317 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKI.TTF) italic normal book normal>) = 11.05
# 2021-03-21 11:59:05,317 - DEBUG: findfont: score(<Font 'Elephant' (ELEPHNTI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,317 - DEBUG: findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,318 - DEBUG: findfont: score(<Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,318 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,318 - DEBUG: findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,319 - DEBUG: findfont: score(<Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,319 - DEBUG: findfont: score(<Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,319 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,320 - DEBUG: findfont: score(<Font 'Corbel' (corbell.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,320 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,320 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,321 - DEBUG: findfont: score(<Font 'Book Antiqua' (BKANT.TTF) normal normal book normal>) = 10.05
# 2021-03-21 11:59:05,321 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,322 - DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal bold condensed>) = 10.535
# 2021-03-21 11:59:05,322 - DEBUG: findfont: score(<Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,322 - DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABKIT.TTF) italic normal book normal>) = 11.05
# 2021-03-21 11:59:05,323 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEDI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,323 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,323 - DEBUG: findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,324 - DEBUG: findfont: score(<Font 'Candara' (Candarali.ttf) italic normal light normal>) = 11.24
# 2021-03-21 11:59:05,324 - DEBUG: findfont: score(<Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,324 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSD.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,325 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,325 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,325 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,326 - DEBUG: findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,326 - DEBUG: findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,326 - DEBUG: findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,327 - DEBUG: findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,327 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,327 - DEBUG: findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,328 - DEBUG: findfont: score(<Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,328 - DEBUG: findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,328 - DEBUG: findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,329 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,329 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,329 - DEBUG: findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
# 2021-03-21 11:59:05,330 - DEBUG: findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,330 - DEBUG: findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,331 - DEBUG: findfont: score(<Font 'Colonna MT' (COLONNA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,331 - DEBUG: findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,331 - DEBUG: findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,332 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal semibold normal>) = 10.24
# 2021-03-21 11:59:05,332 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,332 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,333 - DEBUG: findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,333 - DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWAD.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,333 - DEBUG: findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,334 - DEBUG: findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,334 - DEBUG: findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,334 - DEBUG: findfont: score(<Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,335 - DEBUG: findfont: score(<Font 'Cambria' (cambria.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,335 - DEBUG: findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,335 - DEBUG: findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,336 - DEBUG: findfont: score(<Font 'Palace Script MT' (PALSCRI.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,336 - DEBUG: findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,336 - DEBUG: findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,337 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comicz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,337 - DEBUG: findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2021-03-21 11:59:05,338 - DEBUG: findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal light normal>) = 11.24
# 2021-03-21 11:59:05,338 - DEBUG: findfont: score(<Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,338 - DEBUG: findfont: score(<Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,339 - DEBUG: findfont: score(<Font 'Symbol' (symbol.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,339 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,340 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,340 - DEBUG: findfont: score(<Font 'Algerian' (ALGER.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,340 - DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,341 - DEBUG: findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,341 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,342 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,342 - DEBUG: findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,342 - DEBUG: findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal medium normal>) = 10.145
# 2021-03-21 11:59:05,342 - DEBUG: findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,343 - DEBUG: findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,343 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,344 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal book normal>) = 11.05
# 2021-03-21 11:59:05,344 - DEBUG: findfont: score(<Font 'MS Outlook' (OUTLOOK.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,345 - DEBUG: findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal black normal>) = 10.525
# 2021-03-21 11:59:05,345 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal demi condensed>) = 10.44
# 2021-03-21 11:59:05,345 - DEBUG: findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,346 - DEBUG: findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,346 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,346 - DEBUG: findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,347 - DEBUG: findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2021-03-21 11:59:05,347 - DEBUG: findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,348 - DEBUG: findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,348 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,348 - DEBUG: findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,349 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,349 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal medium normal>) = 10.145
# 2021-03-21 11:59:05,349 - DEBUG: findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,350 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,350 - DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,351 - DEBUG: findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,351 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,352 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_BLAI.TTF) italic normal black normal>) = 11.525
# 2021-03-21 11:59:05,352 - DEBUG: findfont: score(<Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,353 - DEBUG: findfont: score(<Font 'TeamViewer15' (teamviewer15.otf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,353 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILB____.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,354 - DEBUG: findfont: score(<Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,354 - DEBUG: findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,355 - DEBUG: findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,355 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,355 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAXD.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,356 - DEBUG: findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,356 - DEBUG: findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,357 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,357 - DEBUG: findfont: score(<Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,357 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,358 - DEBUG: findfont: score(<Font 'Arial' (ariblk.ttf) normal normal black normal>) = 6.888636363636364
# 2021-03-21 11:59:05,358 - DEBUG: findfont: score(<Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal black normal>) = 10.525
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Leelawadee' (LEELAWDB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,359 - DEBUG: findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,360 - DEBUG: findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,360 - DEBUG: findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,360 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,361 - DEBUG: findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,361 - DEBUG: findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,362 - DEBUG: findfont: score(<Font 'Agency FB' (AGENCYB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,362 - DEBUG: findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,362 - DEBUG: findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal light normal>) = 11.24
# 2021-03-21 11:59:05,363 - DEBUG: findfont: score(<Font 'Ravie' (RAVIE.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,363 - DEBUG: findfont: score(<Font 'Century Schoolbook' (SCHLBKBI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,363 - DEBUG: findfont: score(<Font 'Kristen ITC' (ITCKRIST.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,364 - DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,364 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal book normal>) = 10.05
# 2021-03-21 11:59:05,364 - DEBUG: findfont: score(<Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,365 - DEBUG: findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,365 - DEBUG: findfont: score(<Font 'Franklin Gothic Book' (FRABK.TTF) normal normal book normal>) = 10.05
# 2021-03-21 11:59:05,366 - DEBUG: findfont: score(<Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,366 - DEBUG: findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,367 - DEBUG: findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal heavy normal>) = 10.43
# 2021-03-21 11:59:05,367 - DEBUG: findfont: score(<Font 'Rage Italic' (RAGE.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,367 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CB.TTF) normal normal 700 condensed>) = 10.535
# 2021-03-21 11:59:05,368 - DEBUG: findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,368 - DEBUG: findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,368 - DEBUG: findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,369 - DEBUG: findfont: score(<Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,369 - DEBUG: findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,370 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,370 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,371 - DEBUG: findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,371 - DEBUG: findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,372 - DEBUG: findfont: score(<Font 'Perpetua' (PERI____.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,373 - DEBUG: findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,374 - DEBUG: findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,374 - DEBUG: findfont: score(<Font 'Bradley Hand ITC' (BRADHITC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,375 - DEBUG: findfont: score(<Font 'Centaur' (CENTAUR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,375 - DEBUG: findfont: score(<Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,376 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,376 - DEBUG: findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,376 - DEBUG: findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,377 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,377 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal demi normal>) = 11.24
# 2021-03-21 11:59:05,378 - DEBUG: findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,378 - DEBUG: findfont: score(<Font 'Consolas' (consolai.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,379 - DEBUG: findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,379 - DEBUG: findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2021-03-21 11:59:05,379 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,380 - DEBUG: findfont: score(<Font 'Felix Titling' (FELIXTI.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,380 - DEBUG: findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,381 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,381 - DEBUG: findfont: score(<Font 'Informal Roman' (INFROMAN.TTF) normal normal roman normal>) = 10.145
# 2021-03-21 11:59:05,382 - DEBUG: findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,382 - DEBUG: findfont: score(<Font 'Eras Bold ITC' (ERASBD.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,382 - DEBUG: findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,383 - DEBUG: findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal light normal>) = 11.24
# 2021-03-21 11:59:05,383 - DEBUG: findfont: score(<Font 'Forte' (FORTE.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,384 - DEBUG: findfont: score(<Font 'High Tower Text' (HTOWERTI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,384 - DEBUG: findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,384 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILBI___.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,385 - DEBUG: findfont: score(<Font 'Berlin Sans FB Demi' (BRLNSDB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,386 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal bold condensed>) = 10.535
# 2021-03-21 11:59:05,386 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium Cond' (FRAMDCN.TTF) normal normal medium condensed>) = 10.344999999999999
# 2021-03-21 11:59:05,386 - DEBUG: findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,387 - DEBUG: findfont: score(<Font 'Onyx' (ONYX.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,387 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,387 - DEBUG: findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,388 - DEBUG: findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,388 - DEBUG: findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2021-03-21 11:59:05,389 - DEBUG: findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,389 - DEBUG: findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,389 - DEBUG: findfont: score(<Font 'Lucida Sans' (LSANS.TTF) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,390 - DEBUG: findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,390 - DEBUG: findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,391 - DEBUG: findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,391 - DEBUG: findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,392 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,392 - DEBUG: findfont: score(<Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal 700 condensed>) = 10.535
# 2021-03-21 11:59:05,393 - DEBUG: findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal book normal>) = 11.05
# 2021-03-21 11:59:05,393 - DEBUG: findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 2021-03-21 11:59:05,394 - DEBUG: findfont: score(<Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,394 - DEBUG: findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,394 - DEBUG: findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,395 - DEBUG: findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,395 - DEBUG: findfont: score(<Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,396 - DEBUG: findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,396 - DEBUG: findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,397 - DEBUG: findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,397 - DEBUG: findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,398 - DEBUG: findfont: score(<Font 'Jokerman' (JOKERMAN.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,398 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
# 2021-03-21 11:59:05,398 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,399 - DEBUG: findfont: score(<Font 'Times New Roman' (times.ttf) normal normal roman normal>) = 10.145
# 2021-03-21 11:59:05,399 - DEBUG: findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,400 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
# 2021-03-21 11:59:05,400 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPE.TTF) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,400 - DEBUG: findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,401 - DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,401 - DEBUG: findfont: score(<Font 'Tw Cen MT' (TCBI____.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,402 - DEBUG: findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,402 - DEBUG: findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,402 - DEBUG: findfont: score(<Font 'Microsoft Uighur' (MSUIGHUR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,403 - DEBUG: findfont: score(<Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,404 - DEBUG: findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,405 - DEBUG: findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal book normal>) = 10.05
# 2021-03-21 11:59:05,405 - DEBUG: findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
# 2021-03-21 11:59:05,405 - DEBUG: findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal medium normal>) = 10.145
# 2021-03-21 11:59:05,406 - DEBUG: findfont: score(<Font 'Century Schoolbook' (CENSCBK.TTF) normal normal book normal>) = 10.05
# 2021-03-21 11:59:05,406 - DEBUG: findfont: score(<Font 'Lucida Fax' (LFAX.TTF) normal normal regular normal>) = 10.05
# 2021-03-21 11:59:05,407 - DEBUG: findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,407 - DEBUG: findfont: score(<Font 'Calibri' (calibril.ttf) normal normal light normal>) = 10.24
# 2021-03-21 11:59:05,408 - DEBUG: findfont: score(<Font 'Franklin Gothic Demi' (FRADM.TTF) normal normal demi normal>) = 10.24
# 2021-03-21 11:59:05,408 - DEBUG: findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,408 - DEBUG: findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,409 - DEBUG: findfont: score(<Font 'Berlin Sans FB' (BRLNSR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,409 - DEBUG: findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,410 - DEBUG: findfont: score(<Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,410 - DEBUG: findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal demi normal>) = 10.24
# 2021-03-21 11:59:05,410 - DEBUG: findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,411 - DEBUG: findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,411 - DEBUG: findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal bold normal>) = 10.335
# 2021-03-21 11:59:05,412 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,412 - DEBUG: findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,412 - DEBUG: findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,413 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_B.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,413 - DEBUG: findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal light normal>) = 11.24
# 2021-03-21 11:59:05,413 - DEBUG: findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,414 - DEBUG: findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal medium normal>) = 10.145
# 2021-03-21 11:59:05,414 - DEBUG: findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2021-03-21 11:59:05,415 - DEBUG: findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,415 - DEBUG: findfont: score(<Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,416 - DEBUG: findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2021-03-21 11:59:05,416 - DEBUG: findfont: score(<Font 'Rockwell' (ROCKBI.TTF) italic normal 700 normal>) = 11.335
# 2021-03-21 11:59:05,417 - DEBUG: findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
# 2021-03-21 11:59:05,417 - DEBUG: findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
# 2021-03-21 11:59:05,418 - DEBUG: findfont: score(<Font 'Consolas' (consola.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,418 - DEBUG: findfont: score(<Font 'Californian FB' (CALIFB.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,419 - DEBUG: findfont: score(<Font 'Perpetua' (PERB____.TTF) normal normal 700 normal>) = 10.335
# 2021-03-21 11:59:05,419 - DEBUG: findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2021-03-21 11:59:05,420 - DEBUG: findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,420 - DEBUG: findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal roman normal>) = 11.145
# 2021-03-21 11:59:05,421 - DEBUG: findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
# 2021-03-21 11:59:05,421 - DEBUG: findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal black normal>) = 11.525
# 2021-03-21 11:59:05,422 - DEBUG: findfont: score(<Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal bold condensed>) = 10.535
# 2021-03-21 11:59:05,422 - DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\david\\.conda\\envs\\mynewenv\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'].mean()
# Out:
# inf

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'].median()
# Out:
# 1.2188782489740082

# %%
gdf_car_legs_sample.to_csv("C:/Users/david/Desktop/car_routes_149_04.csv",index=False,mode='w')

# %%
cond = (gdf_car_legs_sample['distance'] > 1000) & (gdf_car_legs_sample['distance'] < 10000)

# %%
gdf_car_legs_sample[cond]['matsim_here_duration_ratio'].mean()
# Out:
# 1.2432941965595479

# %%
gdf_car_legs_sample[cond]['matsim_here_duration_ratio'].median()
# Out:
# 1.1709604216485285
