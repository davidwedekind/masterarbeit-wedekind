# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString
from sqlalchemy import create_engine
import requests
import json
from utils import load_db_parameters

# %%
import logging
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

# %% [markdown]
# ## Read-In data from postgres db

# %%
db_uri = "postgres+psycopg2://postgres:dW49t8@0DPA2@localhost:5432/stuttgart_1pct_calibration"

# %%
engine = create_engine(db_uri, echo=False)

# %%
run_name = "cal_131_12"
query = f'''
        SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = '{run_name}' ;
            '''
print(query)
# Out:
#         SELECT * FROM matsim_output.sim_car_legs_within_modell_area WHERE run_name = 'cal_131_12' ;

# %%
gdf_car_legs = gpd.read_postgis(
    sql=query,
    con=db_uri,
    geom_col="geometry",
    crs="epsg:25832"
)

# %%
gdf_car_legs.head(3)
# Out:
#    index        person         trip_id  dep_time  trav_time  wait_time  \
# 0     64  68794015_726  68794015_726_3     35216       1939          0
# 1   2207   70178040_98   70178040_98_1     34085        652          0
# 2   2210   70178040_98   70178040_98_2     37622        949          0
#
#    distance mode start_link        start_x  ...  access_stop_id  \
# 0     15608  car   16227672  528789.220921  ...            None
# 1      3495  car    4128922  512599.744600  ...            None
# 2      2697  car  108881461  514625.334181  ...            None
#
#   egress_stop_id  transit_line  transit_route  \
# 0           None          None           None
# 1           None          None           None
# 2           None          None           None
#
#                                             geometry arr_time  leg_speed  \
# 0  LINESTRING (528789.221 5395763.622, 516727.138...    37155  28.978236
# 1  LINESTRING (512599.745 5401604.257, 514625.334...    34737  19.297546
# 2  LINESTRING (514625.334 5404052.252, 515752.342...    38571  10.230980
#
#   pt_line pt_group    run_name
# 0    None     None  cal_131_12
# 1    None     None  cal_131_12
# 2    None     None  cal_131_12
#
# [3 rows x 24 columns]

# %% [markdown]
# ## Create 1 % Sample

# %%
frac = 0.1

# %%
gdf_car_legs.columns
# Out:
# Index(['index', 'person', 'trip_id', 'dep_time', 'trav_time', 'wait_time',
#        'distance', 'mode', 'start_link', 'start_x', 'start_y', 'end_link',
#        'end_x', 'end_y', 'access_stop_id', 'egress_stop_id', 'transit_line',
#        'transit_route', 'geometry', 'arr_time', 'leg_speed', 'pt_line',
#        'pt_group', 'run_name'],
#       dtype='object')

# %%
gdf_car_legs_sample = gdf_car_legs[['person', 'trip_id', 'mode', 'dep_time', 'arr_time', 'trav_time', 'distance', 'start_link', 'end_link', 'geometry']].sample(frac=frac)
gdf_car_legs_sample.head(3)
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 3093  73734005_732  73734005_732_4  car     53709     55027       1318
# 629   70569005_207  70569005_207_4  car     76764     76928        164
# 288   70435045_988  70435045_988_3  car     38705     38959        254
#
#       distance start_link   end_link  \
# 3093      6948   31947304  114935850
# 629       1124    8681756    3036796
# 288       1001   91235630    1567391
#
#                                                geometry
# 3093  LINESTRING (525049.180 5398972.020, 522540.779...
# 629   LINESTRING (510766.388 5399217.775, 511299.414...
# 288   LINESTRING (513165.174 5406164.363, 513179.604...

# %% [markdown]
# ## Bring to Here API format

# %%
gdf_car_legs_sample.to_crs("EPSG:4326", inplace=True)

# %% [markdown]
# **Coordinates**

# %%
def return_coord_values(s):
    s["start_x"] = (s['geometry']).coords[0][0]
    s["start_y"] = (s['geometry']).coords[0][1]
    s["end_x"] = (s['geometry']).coords[1][0]
    s["end_y"] = (s['geometry']).coords[1][1]
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(return_coord_values, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 3093  73734005_732  73734005_732_4  car     53709     55027       1318
# 629   70569005_207  70569005_207_4  car     76764     76928        164
# 288   70435045_988  70435045_988_3  car     38705     38959        254
#
#       distance start_link   end_link  \
# 3093      6948   31947304  114935850
# 629       1124    8681756    3036796
# 288       1001   91235630    1567391
#
#                                              geometry   start_x    start_y  \
# 3093  LINESTRING (9.34072 48.74326, 9.30646 48.71978)  9.340723  48.743262
# 629   LINESTRING (9.14645 48.74588, 9.15370 48.74511)  9.146454  48.745883
# 288   LINESTRING (9.17931 48.80833, 9.17952 48.81181)  9.179306  48.808328
#
#          end_x      end_y
# 3093  9.306461  48.719782
# 629   9.153702  48.745110
# 288   9.179515  48.811809

# %% [markdown]
# **Times and Dates**

# %%
date = "2020-02-02"

# %%
def return_here_format_timestamp(time, date):
    hours = (time//3600)%24
    minutes = (time%3600)//60
    seconds = (time%3600)%60
    return date + "T" + str(hours).zfill(2) + ":" + str(minutes).zfill(2) + ":" + str(seconds).zfill(2)

# %%
gdf_car_legs_sample['dep_time_here_format'] = gdf_car_legs_sample['dep_time'].apply(lambda x: return_here_format_timestamp(x, date))

# %% [markdown]
# **API REQUEST STRINGS**

# %%
def build_here_url(apiKey, departure, origin, destination):
    
    BASE_URL_HERE = 'https://router.hereapi.com/v8/routes'
    routingMode = 'fast'
    mode = 'car'
    alternatives = 0
    
    return f'{BASE_URL_HERE}?&apiKey={apiKey}&origin={origin}&destination={destination}&departure={departure}&transportMode={mode}&routingMode={routingMode}&alternatives={alternatives}&return=summary'

# %%
apiKey = "_W_I-ts4uhv5x7PGfNTjIJlpr7nQyvw8dbvQ_vP3QV4"

# %%
gdf_car_legs_sample['api_request_string'] = gdf_car_legs_sample.apply(lambda x: build_here_url(
    apiKey,
    x['dep_time_here_format'],
    str(x['start_y']) + "," + str(x['start_x']),
    str(x['end_y']) + "," + str(x['end_x'])),axis=1)

# %% [markdown]
# ## Process requests

# %%
size = gdf_car_legs_sample.shape[0]
count = 1
 
for index,row in gdf_car_legs_sample.iterrows():
    
    req = requests.get(row['api_request_string'])
    gdf_car_legs_sample.loc[index, 'req_answer']=req.text
    log_condition = (count%10==0) or (count==1) or (count==size)
        
    if (req.status_code != 200):
        print('Request with bad resonse: ' + str(req.status_code))
        print(row['api_request_string'])
        
    if (log_condition):
        print('No of requests processed: ' + str(count))
        
    count = count + 1
# Out:
# No of requests processed: 1
# No of requests processed: 10
# No of requests processed: 20
# No of requests processed: 30
# No of requests processed: 40
# No of requests processed: 50
# No of requests processed: 60
# No of requests processed: 70
# No of requests processed: 80
# No of requests processed: 90
# No of requests processed: 100
# No of requests processed: 110
# No of requests processed: 120
# No of requests processed: 130
# No of requests processed: 140
# No of requests processed: 150
# No of requests processed: 160
# No of requests processed: 170
# No of requests processed: 180
# No of requests processed: 190
# No of requests processed: 200
# No of requests processed: 210
# No of requests processed: 220
# No of requests processed: 230
# No of requests processed: 240
# No of requests processed: 250
# No of requests processed: 260
# No of requests processed: 270
# No of requests processed: 280
# No of requests processed: 290
# No of requests processed: 300
# No of requests processed: 310
# No of requests processed: 320
# No of requests processed: 330
# No of requests processed: 340
# No of requests processed: 350
# No of requests processed: 360
# No of requests processed: 370
# No of requests processed: 380
# No of requests processed: 382

# %%
gdf_car_legs_sample.head(3)
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 3093  73734005_732  73734005_732_4  car     53709     55027       1318
# 629   70569005_207  70569005_207_4  car     76764     76928        164
# 288   70435045_988  70435045_988_3  car     38705     38959        254
#
#       distance start_link   end_link  \
# 3093      6948   31947304  114935850
# 629       1124    8681756    3036796
# 288       1001   91235630    1567391
#
#                                              geometry   start_x    start_y  \
# 3093  LINESTRING (9.34072 48.74326, 9.30646 48.71978)  9.340723  48.743262
# 629   LINESTRING (9.14645 48.74588, 9.15370 48.74511)  9.146454  48.745883
# 288   LINESTRING (9.17931 48.80833, 9.17952 48.81181)  9.179306  48.808328
#
#          end_x      end_y dep_time_here_format  \
# 3093  9.306461  48.719782  2020-02-02T14:55:09
# 629   9.153702  48.745110  2020-02-02T21:19:24
# 288   9.179515  48.811809  2020-02-02T10:45:05
#
#                                      api_request_string  \
# 3093  https://router.hereapi.com/v8/routes?&apiKey=_...
# 629   https://router.hereapi.com/v8/routes?&apiKey=_...
# 288   https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                              req_answer
# 3093  {"routes":[{"id":"8d1d68b1-1aad-42fd-bcad-c125...
# 629   {"routes":[{"id":"c52d3409-a155-42f7-aacd-e4cc...
# 288   {"routes":[{"id":"59ea9401-d6cf-42de-8c91-773d...

# %% [markdown]
# ## Process results

# %%
def extract_relevant_results(s):
    json_answ = json.loads(s['req_answer'])
    s['here_duration'] = json_answ['routes'][0]['sections'][0]['summary']['duration']
    s['here_baseDuration'] = json_answ['routes'][0]['sections'][0]['summary']['baseDuration']
    s['here_length'] = json_answ['routes'][0]['sections'][0]['summary']['length']
    return s

# %%
gdf_car_legs_sample = gdf_car_legs_sample.apply(extract_relevant_results, axis=1)

# %%
gdf_car_legs_sample.head(3)
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 3093  73734005_732  73734005_732_4  car     53709     55027       1318
# 629   70569005_207  70569005_207_4  car     76764     76928        164
# 288   70435045_988  70435045_988_3  car     38705     38959        254
#
#       distance start_link   end_link  \
# 3093      6948   31947304  114935850
# 629       1124    8681756    3036796
# 288       1001   91235630    1567391
#
#                                              geometry   start_x    start_y  \
# 3093  LINESTRING (9.34072 48.74326, 9.30646 48.71978)  9.340723  48.743262
# 629   LINESTRING (9.14645 48.74588, 9.15370 48.74511)  9.146454  48.745883
# 288   LINESTRING (9.17931 48.80833, 9.17952 48.81181)  9.179306  48.808328
#
#          end_x      end_y dep_time_here_format  \
# 3093  9.306461  48.719782  2020-02-02T14:55:09
# 629   9.153702  48.745110  2020-02-02T21:19:24
# 288   9.179515  48.811809  2020-02-02T10:45:05
#
#                                      api_request_string  \
# 3093  https://router.hereapi.com/v8/routes?&apiKey=_...
# 629   https://router.hereapi.com/v8/routes?&apiKey=_...
# 288   https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                              req_answer  here_duration  \
# 3093  {"routes":[{"id":"8d1d68b1-1aad-42fd-bcad-c125...            603
# 629   {"routes":[{"id":"c52d3409-a155-42f7-aacd-e4cc...            196
# 288   {"routes":[{"id":"59ea9401-d6cf-42de-8c91-773d...             99
#
#       here_baseDuration  here_length
# 3093                578         6244
# 629                 195         1110
# 288                  98          630

# %% [markdown]
# ## Statistics

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'] = gdf_car_legs_sample['trav_time']/gdf_car_legs_sample['here_duration']
gdf_car_legs_sample['matsim_here_distance_ratio'] = gdf_car_legs_sample['distance']/gdf_car_legs_sample['here_length']

# %%
gdf_car_legs_sample.head(3)
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 3093  73734005_732  73734005_732_4  car     53709     55027       1318
# 629   70569005_207  70569005_207_4  car     76764     76928        164
# 288   70435045_988  70435045_988_3  car     38705     38959        254
#
#       distance start_link   end_link  \
# 3093      6948   31947304  114935850
# 629       1124    8681756    3036796
# 288       1001   91235630    1567391
#
#                                              geometry  ...     end_x  \
# 3093  LINESTRING (9.34072 48.74326, 9.30646 48.71978)  ...  9.306461
# 629   LINESTRING (9.14645 48.74588, 9.15370 48.74511)  ...  9.153702
# 288   LINESTRING (9.17931 48.80833, 9.17952 48.81181)  ...  9.179515
#
#           end_y  dep_time_here_format  \
# 3093  48.719782   2020-02-02T14:55:09
# 629   48.745110   2020-02-02T21:19:24
# 288   48.811809   2020-02-02T10:45:05
#
#                                      api_request_string  \
# 3093  https://router.hereapi.com/v8/routes?&apiKey=_...
# 629   https://router.hereapi.com/v8/routes?&apiKey=_...
# 288   https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                              req_answer here_duration  \
# 3093  {"routes":[{"id":"8d1d68b1-1aad-42fd-bcad-c125...           603
# 629   {"routes":[{"id":"c52d3409-a155-42f7-aacd-e4cc...           196
# 288   {"routes":[{"id":"59ea9401-d6cf-42de-8c91-773d...            99
#
#      here_baseDuration  here_length  matsim_here_duration_ratio  \
# 3093               578         6244                    2.185738
# 629                195         1110                    0.836735
# 288                 98          630                    2.565657
#
#       matsim_here_distance_ratio
# 3093                    1.112748
# 629                     1.012613
# 288                     1.588889
#
# [3 rows x 22 columns]

# %%
gdf_car_legs_sample.boxplot(column='matsim_here_duration_ratio')

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'].mean()
# Out:
# 1.4113146613144152

# %%
gdf_car_legs_sample['matsim_here_duration_ratio'].median()
# Out:
# 1.2476163229587887

# %%
gdf_car_legs_sample.iloc[20:25,:]
# Out:
#             person         trip_id mode  dep_time  arr_time  trav_time  \
# 695   70599015_322  70599015_322_3  car     68915     69469        554
# 3168  73760015_678  73760015_678_3  car     46126     48027       1901
# 1682  71069045_207  71069045_207_1  car     28636     31027       2391
# 2441   71543025_56   71543025_56_3  car     38445     38714        269
# 2811  73230100_592  73230100_592_2  car     53184     54555       1371
#
#       distance start_link end_link  \
# 695       5628   51644232  5855175
# 3168      8962    6476464  6170490
# 1682     13570    3647139  5913741
# 2441      2436    3372912  3372899
# 2811     14130   42004918  5034879
#
#                                              geometry  ...     end_x  \
# 695   LINESTRING (9.17054 48.70774, 9.21207 48.70260)  ...  9.212066
# 3168  LINESTRING (9.31425 48.69519, 9.30581 48.74018)  ...  9.305810
# 1682  LINESTRING (8.98730 48.72836, 9.06331 48.65984)  ...  9.063315
# 2441  LINESTRING (9.09507 48.82318, 9.11283 48.82435)  ...  9.112834
# 2811  LINESTRING (9.18657 48.77001, 9.20388 48.86947)  ...  9.203884
#
#           end_y  dep_time_here_format  \
# 695   48.702599   2020-02-02T19:08:35
# 3168  48.740181   2020-02-02T12:48:46
# 1682  48.659838   2020-02-02T07:57:16
# 2441  48.824348   2020-02-02T10:40:45
# 2811  48.869472   2020-02-02T14:46:24
#
#                                      api_request_string  \
# 695   https://router.hereapi.com/v8/routes?&apiKey=_...
# 3168  https://router.hereapi.com/v8/routes?&apiKey=_...
# 1682  https://router.hereapi.com/v8/routes?&apiKey=_...
# 2441  https://router.hereapi.com/v8/routes?&apiKey=_...
# 2811  https://router.hereapi.com/v8/routes?&apiKey=_...
#
#                                              req_answer here_duration  \
# 695   {"routes":[{"id":"ceee7d0d-01ee-4ed0-81e0-3673...           503
# 3168  {"routes":[{"id":"6890088f-3643-477f-8808-7dc3...           977
# 1682  {"routes":[{"id":"4b6b2467-144e-4d20-ae9e-4859...          1171
# 2441  {"routes":[{"id":"de777be5-814f-4fca-ac4f-55b1...           264
# 2811  {"routes":[{"id":"4055587a-faec-4139-b910-19b5...          1169
#
#      here_baseDuration  here_length  matsim_here_duration_ratio  \
# 695                494         5842                    1.101392
# 3168               943         8049                    1.945752
# 1682              1100        12807                    2.041845
# 2441               264         1886                    1.018939
# 2811              1117        13825                    1.172797
#
#       matsim_here_distance_ratio
# 695                     0.963369
# 3168                    1.113430
# 1682                    1.059577
# 2441                    1.291622
# 2811                    1.022061
#
# [5 rows x 22 columns]
