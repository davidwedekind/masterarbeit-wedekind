# %%
import matsim
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### Export Network to shape File

# %%
networkPath = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/03_MATSim/02_runs/stuttgart-v1.0/04_stuttgart-v1.0_calibration/input/optimizedNetwork.xml.gz"
outputShape = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/03_MATSim/01_prep/07_Measures/01_street_closure/network.shp"

# %%
net = matsim.read_network(networkPath)

# %%
gdf_geo = net.as_geo()

# %%
gdf_geo = gdf_geo[~gdf_geo["link_id"].str.startswith("tr")]

# %%
gdf_geo.head()

# %%
gdf_geo.to_file(outputShape)

# %% [markdown]
# ### Export again from adjusted shapeFile

# %%
networkPath = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/03_MATSim/02_runs/stuttgart-v1.0/02_stuttgart-v1.0_test/network_w_cars_banned.xml.gz"
outputShape = "C:/Users/david/OneDrive/02_Uni/02_Master/05_Masterarbeit/03_MATSim/01_prep/07_Measures/01_street_closure/network_adjusted.shp"

# %%
net = matsim.read_network(networkPath)

# %%
gdf_geo = net.as_geo()

# %%
gdf_geo = gdf_geo[~gdf_geo["link_id"].str.startswith("tr")]

# %%
gdf_geo.head()
# Out:
#    length  freespeed  capacity  permlanes oneway     modes    link_id  \
# 0   50.53       9.47    1200.0        2.0      1  car,ride   10000014
# 1   43.77       9.48     600.0        1.0      1  car,ride  120628180
# 2   61.02       9.56    1200.0        2.0      1  car,ride   10000015
# 3   31.49       5.70    1200.0        2.0      1  car,ride   69483004
# 4   41.14       5.71    1200.0        2.0      1  car,ride   82780285
#
#     from_node     to_node                                           geometry
# 0  1944304351  1856452849  LINESTRING (477508.123 5466441.289, 477459.281...
# 1  1731805232  1856452849  LINESTRING (477416.113 5466442.390, 477459.281...
# 2  1944304351   269775762  LINESTRING (477508.123 5466441.289, 477557.847...
# 3  1834445603   269775762  LINESTRING (477572.063 5466378.392, 477557.847...
# 4  1944304351  1944304386  LINESTRING (477508.123 5466441.289, 477542.612...

# %%
gdf_geo[gdf_geo['modes']=='']
# Out:
#         length  freespeed  capacity  permlanes oneway modes    link_id  \
# 1858    108.51       9.76     600.0        1.0      1        100138226
# 1859     67.56       9.66     600.0        1.0      1        100138231
# 1860     86.60       3.87     300.0        1.0      1          4247693
# 1861      7.69       5.74     600.0        1.0      1         14628661
# 1862    120.15       5.85     600.0        1.0      1         14628654
# ...        ...        ...       ...        ...    ...   ...        ...
# 680401  148.60       6.29     600.0        1.0      1           949388
# 681579   65.91       8.07     600.0        1.0      1         97278970
# 682339   55.20       6.14     600.0        1.0      1         99027742
# 682538  100.05       6.44     600.0        1.0      1         99363397
# 682539  100.05       6.50     600.0        1.0      1         99363376
#
#          from_node     to_node  \
# 1858    2811837864   130096531
# 1859     130096216   130096531
# 1860     130440589   130096531
# 1861    2811837864   344460696
# 1862     130441539   344460696
# ...            ...         ...
# 680401    30983916  1692365548
# 681579   319791424  1386647159
# 682339  2721781042  2721781045
# 682538   250363427  2402379595
# 682539  2402379595   250363427
#
#                                                  geometry
# 1858    LINESTRING (501669.026 5392251.792, 501777.422...
# 1859    LINESTRING (501844.925 5392259.217, 501777.422...
# 1860    LINESTRING (501775.529 5392169.967, 501777.422...
# 1861    LINESTRING (501669.026 5392251.792, 501661.364...
# 1862    LINESTRING (501546.512 5392216.331, 501661.364...
# ...                                                   ...
# 680401  LINESTRING (510400.534 5394625.020, 510380.396...
# 681579  LINESTRING (499104.784 5394598.278, 499076.801...
# 682339  LINESTRING (525107.522 5398024.430, 525152.233...
# 682538  LINESTRING (520075.212 5399540.065, 520101.800...
# 682539  LINESTRING (520101.800 5399444.139, 520075.212...
#
# [11079 rows x 10 columns]

# %%
gdf_geo.to_file(outputShape)
